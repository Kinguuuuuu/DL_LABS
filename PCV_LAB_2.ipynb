# %% [markdown]
# # ID NO : 190031226
# # NAME  : PAKALAPATI MAHIDHAR
# # PERCEPTION AND COMPUTER VISION LAB - 2

# %% [markdown]
# ### 1. Read an input color (RGB) image

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('tomjerry.png')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
print(img_rgb.shape)
# Out:
# (252, 257, 3)

# %%
from google.colab.patches import cv2_imshow

# %% [markdown]
# ### 2. Convert the read image to YCrCb color space

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('tomjerry.png')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_YCrCb = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2YCrCb)
plt.imshow(img_YCrCb)
print(img_YCrCb.shape)
# Out:
# (252, 257, 3)

# %% [markdown]
# ### 3. Convert the read image to HSV color space

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('tomjerry.png')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_hsv = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2HSV)
plt.imshow(img_hsv)
print(img_hsv.shape)
# Out:
# (252, 257, 3)

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('tomjerry.png')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_lab = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2LAB)
plt.imshow(img_lab)
print(img_lab.shape)
# Out:
# (252, 257, 3)

# %%
img0 = cv2.imread('tomjerry.png')

# %%
gray = cv2.cvtColor(img0, cv2.COLOR_BGR2GRAY)

# remove noise
img = cv2.GaussianBlur(gray,(3,3),0)

# convolute with proper kernels
laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)  # x
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)  # y

plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
import matplotlib.pyplot as plt
import cv2
  
# reads the image
img = cv2.imread('tomjerry.png')
  
# plot heat map image
plt.imshow(img, cmap ='hot')

# %%
import cv2

image = cv2.imread('tomjerry.png', 1)
heatmap = cv2.applyColorMap(image, cv2.COLORMAP_HOT)

cv2_imshow(heatmap)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=RGB size=257x252 at 0x7F6E1E3B8690>
# -1

# %%
import matplotlib.pyplot as plt
import cv2
  
img = cv2.imread('tomjerry.png')
plt.imshow(img, cmap ='nipy_spectral')

# %% [markdown]
# POST LAB

# %%
import cv2
import numpy as np

# read image
img = cv2.imread('tomjerry.png')

mask1 = cv2.imread('tomjerry.png',0)
result1 = img.copy()
result1[mask1 == 0] = 0
result1[mask1 != 0] = img[mask1 != 0]

mask2 = cv2.imread('tomjerry.png') / 255.0

cv2_imshow(mask1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# save results
cv2.imwrite('tomjerry.png', result1)
# Out:
# <PIL.Image.Image image mode=L size=257x252 at 0x7F6E1E2A7210>
# True

# %%
import cv2
import numpy as np

# read image
img = cv2.imread('tomjerry.png')

mask1 = cv2.imread('tomjerry.png',0)
result1 = img.copy()
result1[mask1 == 0] = 0
result1[mask1 != 0] = img[mask1 != 0]

mask2 = cv2.imread('tomjerry.png') / 255.0

cv2_imshow(result1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# save results
cv2.imwrite('tomjerry.png', result1)
# Out:
# <PIL.Image.Image image mode=RGB size=257x252 at 0x7F6E1E214D90>
# True

# %%
import cv2
import numpy as np

# read image
img = cv2.imread('tomjerry.png')

mask1 = cv2.imread('tomjerry.png',0)
result1 = img.copy()
result1[mask1 == 0] = 0
result1[mask1 != 0] = img[mask1 != 0]

mask2 = cv2.imread('tomjerry.png') / 255.0
result2 = (img * mask2).clip(0, 255).astype(np.uint8)

cv2_imshow(img)
cv2_imshow(mask1)
cv2_imshow(result1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# save results
cv2.imwrite('tomjerry.png', result1)
# Out:
# <PIL.Image.Image image mode=RGB size=257x252 at 0x7F6E1E21EC10>
# <PIL.Image.Image image mode=L size=257x252 at 0x7F6E1E21ED50>
# <PIL.Image.Image image mode=RGB size=257x252 at 0x7F6E1E214A50>
# True

# %%
import skimage.io
image = skimage.io.imread('tomjerry.png')

# display the image
fig, ax = plt.subplots()
plt.imshow(image)
plt.show()

colors = ("red", "green", "blue")
channel_ids = (0, 1, 2)

# create the histogram plot, with three lines, one for
# each color
plt.figure()
plt.xlim([0, 256])
for channel_id, c in zip(channel_ids, colors):
    histogram, bin_edges = np.histogram(
        image[:, :, channel_id], bins=256, range=(0, 256)
    )
    plt.plot(bin_edges[0:-1], histogram, color=c)

plt.title("Color Histogram")
plt.xlabel("Color value")
plt.ylabel("Pixel count")

plt.show()
